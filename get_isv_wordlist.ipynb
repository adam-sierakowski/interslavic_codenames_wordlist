# %%
import pandas as pd

# %%
original_df = pd.read_csv("input/new_interslavic_words_list_words.csv")
noun_tag__pattern = r"(?=\bm\.|\banim\.|\bf\.|\bn\.|\bsg\.|\bpl\.|\bindecl\.)"
nouns_df = original_df[original_df["partOfSpeech"].str.contains(noun_tag__pattern, na=False)]
del(original_df)

columns_to_lower = ["en", "pl", "ru", "cs"]
for col in columns_to_lower:
    nouns_df[f"{col}_lower"] = nouns_df[col].str.lower()

nouns_df.head()
# Out:
#       id         isv addition partOfSpeech type                        en  \
# 2  24020        abak      NaN           m.    1                    abacus
# 3   6114      abažur      NaN           m.    1                 lampshade
# 4  35658  abdikacija      NaN           f.    1                abdication
# 6  35691     abeceda      NaN           f.    2  alphabet (usually Latin)
# 7  24026       Abhaz      NaN      m.anim.    1                    Abkhaz
#
#   sameInLanguages genesis                                         ru  \
# 2           v z j       I                         счёты, абак, абака
# 3             NaN       F                                     абажур
# 4             NaN       I  отречение, абдикация, сложение полномочий
# 6             NaN     NaN                  алфавит (обычно латиница)
# 7           v z j     NaN                             абхаз, абхазец
#
#                                                   be  ...  \
# 2                                               абак  ...
# 3                                             абажур  ...
# 4  абдыкацыя, вырачэнне, адрачэнне, адпінанне, вы...  ...
# 6              абэцэда, абяцадла, азбука (лацінская)  ...
# 7                                              абхаз  ...
#
#                                       de                              nl  \
# 2                                 Abakus                         telraam
# 3                           Lampenschirm                       lampenkap
# 4                              Abdankung             aftreden, abdicatie
# 6  Alphabet (gewöhnlich das lateinische)  alfabet (meestal Latijns), abc
# 7                                Abchase                       Abchaziër
#
#              eo frequency intelligibility using_example  \
# 2         abako      1504               !           NaN
# 3  lampoŝirmilo      2030               !           NaN
# 4        abdiko      2586               !           NaN
# 6         aboco      4344               !           NaN
# 7        abĥazo       830               !           NaN
#
#                    en_lower      pl_lower  \
# 2                    abacus  abak, abakus
# 3                 lampshade        abażur
# 4                abdication     abdykacja
# 6  alphabet (usually latin)      abecadło
# 7                    abkhaz        abchaz
#
#                                     ru_lower  \
# 2                         счёты, абак, абака
# 3                                     абажур
# 4  отречение, абдикация, сложение полномочий
# 6                  алфавит (обычно латиница)
# 7                             абхаз, абхазец
#
#                                  cs_lower
# 2                       počítadlo, abakus
# 3  stínidlo, stínítko, abažúr (zastarale)
# 4                                abdikace
# 6                                 abeceda
# 7                                abcházec
#
# [5 rows x 30 columns]

# %%
input_wordlists = [
     "input/codenames_wordlist_cz.txt",
     "input/codenames_wordlist_en.txt",
     "input/codenames_wordlist_pl.txt",
     "input/codenames_wordlist_ru.txt"
]

wordlist_cz, wordlist_en, wordlist_pl, wordlist_ru = [
    pd.read_csv(input_wordlist, header=None) for input_wordlist in input_wordlists
]

wordlists = [wordlist_cz, wordlist_en, wordlist_pl, wordlist_ru]

for wordlist in wordlists:
    wordlist[0] = wordlist[0].str.lower()
    wordlist.rename(columns={0: "wordlist"}, inplace=True)

wordlist_cz, wordlist_en, wordlist_pl, wordlist_ru = wordlists

# %%
nouns_from_cz = pd.merge(nouns_df, wordlist_cz, left_on='cs_lower', right_on='wordlist')
nouns_from_pl = pd.merge(nouns_df, wordlist_pl, left_on='pl_lower', right_on='wordlist')
nouns_from_en = pd.merge(nouns_df, wordlist_en, left_on='en_lower', right_on='wordlist')
nouns_from_ru = pd.merge(nouns_df, wordlist_ru, left_on='ru_lower', right_on='wordlist')

# %%
nouns_combined = pd.concat([nouns_from_cz, nouns_from_pl, nouns_from_en, nouns_from_ru], ignore_index=True)
nouns_combined.drop(columns=["wordlist", "cs_lower", "pl_lower", "en_lower", "ru_lower"], inplace=True)
nouns_combined = nouns_combined.reset_index(drop=True).drop_duplicates()

# all_isv_nouns = list(nouns_combined["isv"])
# for noun in all_isv_nouns:
#     if "đ" in noun:
#         print(noun)

# %%
def unetymologize_spelling(word):
    replacement_dict = {
      "ȯ": "o",
      "ŕ": "r",
      "å": "a",
      "ė": "e",
      "ų": "u",
      "ź": "z",
      "ć": "č",
      "đ": "dž",
      "ę": "e",
      "ś": "s",
      "ń": "n",
      "#": ""
    }
    for k, v in replacement_dict.items():
        word = word.replace(k, v)
    return(word)

nouns_combined["standard_spelling_isv"] = nouns_combined["isv"].apply(unetymologize_spelling)

cols = list(nouns_combined.columns)
cols.insert(1, cols.pop(cols.index("standard_spelling_isv")))
nouns_combined = nouns_combined[cols]

nouns_combined = nouns_combined[~nouns_combined["isv"].str.contains(" ", na=False)]

# %%
nouns_combined.sort_values(by="pl").tail(50)
# Out:
#          id standard_spelling_isv          isv addition partOfSpeech type  \
# 271   19179                veriga       veriga      NaN           f.    2
# 1396  17723                lancuh       lancuh      NaN           m.    2
# 1397  17724                 lanec       #lanėc      NaN           m.    3
# 578   27309                 losos        losoś      NaN      m.anim.    1
# 130     386                   los          loś      NaN      m.anim.    1
# 585   36646           lukostrělec  lųkostrělėc      NaN      m.anim.    1
# 131    1893                ložica       lȯžica      NaN           f.    1
# 132     353                 ložka        lȯžka      NaN           f.    1
# 1407   2886                 lodka        lodka      NaN           f.    1
# 373   25037                  čoln         čȯln      NaN           m.    1
# 564    2427               ležišče      ležišče      NaN           n.    3
# 720   11012               postelj      postelj      NaN           f.    1
# 582   20429                  lože         lože      NaN           n.    1
# 133     376                  luka         lųka      NaN           f.    2
# 126   14683                livada       livada      NaN           f.    2
# 1206   1406                 stěna        stěna      NaN           f.    1
# 799   21577                  slěd         slěd      NaN           m.    1
# 800   18839                slimak       slimak      NaN      m.anim.    2
# 713   18303                  polž         pȯlž      NaN      m.anim.    2
# 803     425                  směh         směh      NaN           m.    1
# 237    2070                  smrť         smŕť      NaN           f.    1
# 920   14192              zautraka     zautraka      NaN           f.    1
# 806   18852              snědańje     snědańje      NaN           n.    2
# 238    2209                  sněg         sněg      NaN           m.    1
# 190    1469                 pěvec        pěvėc      NaN      m.anim.    1
# 1303   1263                 centr        centr      NaN           m.    2
# 169   32868               odvrtka      odvŕtka      NaN           f.    1
# 832    3137                  svět         svět      NaN           m.    1
# 251    3284                světlo       světlo      NaN           n.    1
# 1513   1744                 svěča        svěća      NaN           f.    1
# 236   26370                 smrěk        smrěk      NaN           m.    1
# 1517   1438                svinja       svinja      NaN           f.    1
# 1013   4890                  hram         hram      NaN           m.    1
# 935    2626                  žaba         žaba      NaN           f.    1
# 993   36201                faklja       faklja      NaN           f.    1
# 937   19405                  žart         žart      NaN           m.    2
# 936   19404               žarovka      žarovka      NaN           f.    2
# 215   22794                prosak       prośak      NaN      m.anim.    1
# 298   22795                žebrak       žebrak      NaN      m.anim.    2
# 222    1045                 rebro        rebro      NaN           n.    1
# 1330  34722                   gel          gel      NaN           m.    1
# 299     395                želězo       želězo      NaN        n.sg.    1
# 940      16               želudok      želųdȯk      NaN           m.    1
# 301   15743                   žuk          žuk      NaN      m.anim.    2
# 22    17177                  buba         buba      NaN           f.    2
# 1271   1201                 žerav        žerav      NaN      m.anim.    1
# 1272  14387                 žiťje        žiťje      NaN           n.    1
# 941   20836                žirafa       žirafa      NaN           f.    1
# 1274   1996                 život        život      NaN           m.    2
# 300   20837                  žolv         žȯlv      NaN           f.    1
#
#                    en       sameInLanguages genesis  \
# 271             chain                   v j     NaN
# 1396            chain                 ub pl     NaN
# 1397            chain                 sh bm     NaN
# 578            salmon                   NaN     NaN
# 130        elk, moose                   NaN     NaN
# 585            archer                 v z j     NaN
# 131             spoon                   NaN     NaN
# 132             spoon                   NaN     NaN
# 1407             boat                   NaN     NaN
# 373              boat            v cs yu bm     NaN
# 564               bed                    sl     NaN
# 720               bed                   NaN     NaN
# 582               bed                v z sh     NaN
# 133            meadow                     z     NaN
# 126            meadow                  uk j     NaN
# 1206             wall                   NaN     NaN
# 799      trace, track                   NaN     NaN
# 800       snail, slug                  ub z     NaN
# 713             snail                     j     NaN
# 803   laugh, laughter                   NaN     NaN
# 237             death                   NaN     NaN
# 920         breakfast                   NaN     NaN
# 806         breakfast                  ub z     NaN
# 238              snow                   NaN     NaN
# 190       singer (m.)                 v z j     NaN
# 1303   centre, center                   NaN       I
# 169       screwdriver       ru be sh bm uk~     NaN
# 832             world                   NaN     NaN
# 251             light                   NaN     NaN
# 1513           candle                   NaN     NaN
# 236            spruce                   NaN     NaN
# 1517              pig                   NaN     NaN
# 1013           temple                   NaN     NaN
# 935              frog                ub z j     NaN
# 993             torch                 v z j       G
# 937              joke                  ub z       D
# 936        light-bulb                  v yu     NaN
# 215            beggar  ru~ be~ uk hsb sh bm     NaN
# 298            beggar                  ub z     NaN
# 222               rib                   NaN     NaN
# 1330              gel                   NaN       I
# 299              iron                 v z j     NaN
# 940           stomach            ru z yu mk     NaN
# 301               bug                  v pl       S
# 22                bug                     j     NaN
# 1271            crane                 v z j     NaN
# 1272             life                   v z     NaN
# 941           giraffe                 v z j       I
# 1274             life               z sh bm     NaN
# 300            turtle                   z j     NaN
#
#                                ru  ...                             sr  \
# 271                          цепь  ...          верига, ланац, синџир
# 1396                         цепь  ...                          ланац
# 1397                         цепь  ...                          ланац
# 578                        лосось  ...                          лосос
# 130                          лось  ...                            лос
# 585       лучник, стрелок из лука  ...         стрелац (лук и стрела)
# 131                         ложка  ...                  кашика, жлица
# 132                         ложка  ...                  кашика, жлица
# 1407                        лодка  ...             лађа, чамац, чунак
# 373           чёлн, челнок, лодка  ...                          чамац
# 564              кровать, постель  ...                кревет, постеља
# 720              постель, кровать  ...                постеља, кревет
# 582        постель, кровать, ложе  ...  лежај, постеља, кревет, ложај
# 133                           луг  ...                         ливада
# 126                           луг  ...                         ливада
# 1206                        стена  ...                            зид
# 799                          след  ...                           траг
# 800               слизень, улитка  ...                            пуж
# 713                        улитка  ...                            пуж
# 803                   смех, хохот  ...                           смех
# 237                        смерть  ...                           смрт
# 920                       завтрак  ...                        доручак
# 806                       завтрак  ...                        доручак
# 238                          снег  ...                           снег
# 190                         певец  ...                          певач
# 1303                        центр  ...               средиште, центар
# 169                      отвёртка  ...    одвртач, одвијач, шрафцигер
# 832               мир, свет (мир)  ...                           свет
# 251                          свет  ...                         светло
# 1513                        свеча  ...                          свећа
# 236                     ель, ёлка  ...                  смрча, смрека
# 1517                       свинья  ...                          свиња
# 1013                храм, церковь  ...                           храм
# 935                 лягушка, жаба  ...                           жаба
# 993                         факел  ...                          бакља
# 937                         шутка  ...  шала, шега, досетка, лакрдија
# 936   лампочка, лампа накаливания  ...                       сијалица
# 215             попрошайка, нищий  ...                        просјак
# 298     нищий, попрошайка, бедняк  ...                        просјак
# 222                         ребро  ...                          ребро
# 1330                         гель  ...             гел, желе, желатин
# 299                        железо  ...                 гвожђе, железо
# 940                       желудок  ...                        желудац
# 301                           жук  ...                           буба
# 22                            жук  ...                           буба
# 1271                      журавль  ...                          ждрал
# 1272                        жизнь  ...                          живот
# 941                         жираф  ...                         жирафа
# 1274                        жизнь  ...                          живот
# 300                      черепаха  ...                        корњача
#
#                             mk                              bg      cu  \
# 271      верига, синџир, ланец                          верига  верига
# 1396     ланец, синџир, верига                   ланец, верига  верига
# 1397     ланец, синџир, верига                   ланец, верига  верига
# 578                      лосос                          сьомга       !
# 130                        лос                             лос       !
# 585        стрелец (со стрели)                         стрелец       !
# 131                     лажица                          лъжица       !
# 132                     лажица                          лъжица       !
# 1407  лотка, кајче, чун, чамец                           лодка       !
# 373                 чун, чамец                           лодка       !
# 564     лежиште, легло. кревет                           легло       !
# 720            постела, кревет                          !легло       !
# 582                     кревет                           легло       !
# 133                     ливада                          ливада       !
# 126                     ливада                          ливада       !
# 1206                       ѕид                          !стени       !
# 799                      трага               !следа, отпечатък       !
# 800              полжав, голич                   охлюв, плужек       !
# 713                     полжав                          !охлюв       !
# 803                       смеа                     !смях, смях       !
# 237                       смрт                        !смъртта       !
# 920                    појадок                         закуска       !
# 806                    појадок                        !закуска       !
# 238                       снег                           !сняг       !
# 190                      пејач                           певец       !
# 1303          центар, средиште                          център       !
# 169         одвртка, шрафцигер                       !отвертка       !
# 832                       свет                           !свят       !
# 251           светло, светлина                       !светлина       !
# 1513                     свеќа                           !свещ       !
# 236             смрча, оморика                          !ядоха       !
# 1517                     свиња                          !прасе       !
# 1013                      храм                            храм       !
# 935                       жаба                            жаба       !
# 993                      факел                           факел       !
# 937                  виц, шега               шега, смешка, виц       !
# 936         сијалица, светилка                          крушка       !
# 215                    просјак               !крадец на дребно       !
# 298                    просјак                          просяк       !
# 222                      ребро                            !Риб       !
# 1330                       гел                             гел       !
# 299                     железо                          желязо  желѣзо
# 940                   желудник  корем, търбух, желъдък, стомах       !
# 301                    бубачка             насекомо, буболечка       !
# 22                     бубачка           буба, гадина, гадинка       !
# 1271                     жерав                           жерав       !
# 1272                     живот                           живот       !
# 941                     жирафа                           жираф       !
# 1274                     живот                           живот       !
# 300                      желка               костенурка, желва       !
#
#                     de                nl                 eo frequency  \
# 271              Kette    ketting, keten               ĉeno      5404
# 1396             Kette    ketting, keten               ĉeno      5074
# 1397             Kette    ketting, keten               ĉeno      5074
# 578             !Lachs              zalm             !salmo      5375
# 130        !Elch, Elch             eland        !alko, alko      7022
# 585      !Bogenschütze      boogschutter         pafarkisto      4535
# 131            !Löffel             lepel             kulero      5552
# 132            !Löffel             lepel             kulero      5560
# 1407              Boot              boot             !boato      4841
# 373               Boot              boot             !boato      6165
# 564              !Bett               bed              !lito      5434
# 720              !Bett               bed              !lito      5538
# 582              !Bett               bed               lito      5502
# 133             !Wiese      wei, weiland            herbejo      6026
# 126             !Wiese      wei, weiland           !herbejo      5542
# 1206              Wand              wand              !muro      6838
# 799        !Spur, Spur             spoor     !spuron, trako      6552
# 800           Schnecke              slak     !heliko, posta      3170
# 713          !Schnecke              slak            !heliko      4552
# 803    !Lachen, Lachen      lach, gelach       !rido ridado      6102
# 237                Tod              dood             !morto      8314
# 920         !Frühstück           ontbijt        !matenmanĝo      6694
# 806         !Frühstück           ontbijt        !matenmanĝo      6694
# 238             Schnee            sneeuw              !neĝo      7086
# 190             Sänger            zanger          !kantisto      6596
# 1303           Zentrum           centrum    !centro, centro      7589
# 169   !Schraubendreher  schroevendraaier         !ŝraŭbilon      3209
# 832               Welt            wereld             !mondo      8936
# 251             !Licht             licht              !lumo      7714
# 1513            !Kerze             kaars           !kandelo      4940
# 236             Fichte              spar             !piceo      3727
# 1517          !Schwein            varken             !porko      5141
# 1013            Tempel            tempel            !templo      6857
# 935             Frosch            kikker               rano      5796
# 993             Fackel            toorts            !torĉon      3839
# 937             Scherz     grap, scherts              ŝerco      5061
# 936     !die Glühbirne         gloeilamp  ampolo (lumigilo)      5058
# 215           !Bettler          bedelaar          !almozulo      4984
# 298           !Bettler          bedelaar           almozulo      4879
# 222             !Rippe               rib              !ripo      4807
# 1330              !Gel               gel              !ĝelo      5290
# 299              Eisen             ijzer               fero      5956
# 940              Bauch              maag            stomako      5775
# 301            !Fehler        kever, tor         koleoptero      5790
# 22              Fehler        kever, tor               !bug      4555
# 1271             !Kran        kraanvogel               gruo      4039
# 1272             Leben             leven               vivo      8225
# 941            Giraffe             giraf             ĝirafo      4208
# 1274             Leben             leven               vivo      8811
# 300        Schildkröte         schildpad            testudo      5329
#
#      intelligibility using_example
# 271                !           NaN
# 1396               !           NaN
# 1397               !           NaN
# 578                !           NaN
# 130                !           NaN
# 585                !           NaN
# 131                !           NaN
# 132                !           NaN
# 1407               !           NaN
# 373                !           NaN
# 564                !           NaN
# 720                !           NaN
# 582                !           NaN
# 133                !           NaN
# 126                !           NaN
# 1206               !           NaN
# 799                !           NaN
# 800                !           NaN
# 713                !           NaN
# 803                !           NaN
# 237                !           NaN
# 920                !           NaN
# 806                !           NaN
# 238                !           NaN
# 190                !           NaN
# 1303               !           NaN
# 169                !           NaN
# 832                !           NaN
# 251                !           NaN
# 1513               !           NaN
# 236                !           NaN
# 1517               !           NaN
# 1013               !           NaN
# 935                !           NaN
# 993                !           NaN
# 937                !           NaN
# 936                !           NaN
# 215                !           NaN
# 298                !           NaN
# 222                !           NaN
# 1330               !           NaN
# 299                !           NaN
# 940                !           NaN
# 301                !           NaN
# 22                 !           NaN
# 1271               !           NaN
# 1272               !           NaN
# 941                !           NaN
# 1274               !           NaN
# 300                !           NaN
#
# [50 rows x 27 columns]

# %%
nouns_combined.to_csv("output/nouns_info.csv")

# %%
nouns_combined = nouns_combined.groupby('standard_spelling_isv', as_index=False).first()

# %%
def merge_synonyms(df, by_lang, other_cols):
    agg_dict = {col: 'first' for col in other_cols if col not in ['standard_spelling_isv','isv']}
    agg_dict['standard_spelling_isv'] = lambda x: ' / '.join(x.dropna().unique())
    agg_dict['isv'] = lambda x: ' / '.join(x.dropna().unique())
    merged = df.groupby(by_lang, as_index=False).agg(agg_dict)
    cols = ['standard_spelling_isv', 'isv'] + [c for c in merged.columns if c not in ['standard_spelling_isv', 'isv']]
    return merged[cols]

other_columns = ['id', 'addition', 'partOfSpeech', 'type', 'en', 'sameInLanguages', 'genesis', 'ru', 'be', 'uk', 'pl', 'cs', 'sk', 'sl', 'hr', 'sr', 'mk', 'bg', 'cu', 'de', 'nl', 'eo', 'frequency', 'intelligibility', 'using_example']

langs_to_merge_by = ["pl", "cs", "ru"]  # exclude English, as treats "raz" as a synonym of "čas"

for lang in langs_to_merge_by:
    nouns_combined = merge_synonyms(nouns_combined, lang, other_columns)

# %%
nouns_combined.sort_values(by="pl").tail(50)
# Out:
#                    standard_spelling_isv                                  isv  \
# 706                                směna                                směna
# 789  izniščeńje / razrušeńje / uniščeńje  izniščeńje / råzrušeńje / uniščeńje
# 253                                zombi                                zombi
# 743                       polivka / supa                       polivka / supa
# 226                             životina                             životina
# 254                                  zub                                  zųb
# 252                                zlato                                zlåto
# 27                               Latvija                              Latvija
# 387                                labeď                                labęď
# 386                                 lapa                                 lapa
# 698                                lavka                                lavka
# 831              veriga / lancuh / lanec             veriga / lancuh / #lanėc
# 404                                losos                                losoś
# 405                                  los                                  loś
# 410                          lukostrělec                          lųkostrělėc
# 402                       ložica / ložka                       lȯžica / lȯžka
# 401                                lodka                                lodka
# 850                                 čoln                                 čȯln
# 364             ležišče / lože / postelj             ležišče / lože / postelj
# 406                        livada / luka                        livada / lųka
# 727                                stěna                                stěna
# 702                                 slěd                                 slěd
# 786                        polž / slimak                        pȯlž / slimak
# 708                                 směh                                 směh
# 707                                 smrť                                 smŕť
# 234                  snědańje / zautraka                  snědańje / zautraka
# 709                                 sněg                                 sněg
# 539                                pěvec                                pěvėc
# 830                     centr / srědišče                     centr / srědišče
# 520                              odvrtka                              odvŕtka
# 442                                 svět                                 svět
# 682                               světlo                               světlo
# 683                                svěča                                svěća
# 222                                smrěk                                smrěk
# 685                               svinja                               svinja
# 826                                 hram                                 hram
# 413                                 žaba                                 žaba
# 799                               faklja                               faklja
# 863                                 žart                                 žart
# 385                              žarovka                              žarovka
# 598                      prosak / žebrak                      prośak / žebrak
# 648                                rebro                                rebro
# 156                                  gel                                  gel
# 223                               želězo                               želězo
# 224                              želudok                              želųdȯk
# 230                           žuk / buba                           žuk / buba
# 231                                žerav                                žerav
# 228                        žiťje / život                        žiťje / život
# 229                               žirafa                               žirafa
# 844                                 žolv                                 žȯlv
#
#         id addition    partOfSpeech type                         en  \
# 706  20703     None              f.    1            shift (factory)
# 789  35758     None              n.    1  destruction, annihilation
# 253  36297     None  m.anim.indecl.    1                     zombie
# 743  20605     None              f.    2                       soup
# 226   1464     None              f.    1                     animal
# 254   1848     None              m.    1                      tooth
# 252   3046     None           n.sg.    1                       gold
# 27     879     None           f.sg.    1                     Latvia
# 387   1303     None         m.anim.    1                       swan
# 386    502     None              f.    1                        paw
# 698  27062     None              f.    1                      bench
# 831  19179     None              f.    2                      chain
# 404  27309     None         m.anim.    1                     salmon
# 405    386     None         m.anim.    1                 elk, moose
# 410  36646     None         m.anim.    1                     archer
# 402   1893     None              f.    1                      spoon
# 401   2886     None              f.    1                       boat
# 850  25037     None              m.    1                       boat
# 364   2427     None              n.    3                        bed
# 406  14683     None              f.    2                     meadow
# 727   1406     None              f.    1                       wall
# 702  21577     None              m.    1               trace, track
# 786  18303     None         m.anim.    2                      snail
# 708    425     None              m.    1            laugh, laughter
# 707   2070     None              f.    1                      death
# 234  18852     None              n.    2                  breakfast
# 709   2209     None              m.    1                       snow
# 539   1469     None         m.anim.    1                singer (m.)
# 830   1263     None              m.    2             centre, center
# 520  32868     None              f.    1                screwdriver
# 442   3137     None              m.    1                      world
# 682   3284     None              n.    1                      light
# 683   1744     None              f.    1                     candle
# 222  26370     None              m.    1                     spruce
# 685   1438     None              f.    1                        pig
# 826   4890     None              m.    1                     temple
# 413   2626     None              f.    1                       frog
# 799  36201     None              f.    1                      torch
# 863  19405     None              m.    2                       joke
# 385  19404     None              f.    2                 light-bulb
# 598  22794     None         m.anim.    1                     beggar
# 648   1045     None              n.    1                        rib
# 156  34722     None              m.    1                        gel
# 223    395     None           n.sg.    1                       iron
# 224     16     None              m.    1                    stomach
# 230  15743     None         m.anim.    2                        bug
# 231   1201     None         m.anim.    1                      crane
# 228  14387     None              n.    1                       life
# 229  20836     None              f.    1                    giraffe
# 844  20837     None              f.    1                     turtle
#
#           sameInLanguages genesis                                    ru  ...  \
# 706                  None    None                     смена (на заводе)  ...
# 789            ub z yu mk    None  уничтожение, истребление, разрушение  ...
# 253                 v z j       I                                 зомби  ...
# 743                  z sh    None                         суп, похлёбка  ...
# 226           ru uk sh bm    None                              животное  ...
# 254                  None    None                                   зуб  ...
# 252                 v z j    None                                золото  ...
# 27                   None    None                                Латвия  ...
# 387                  None    None                                лебедь  ...
# 386                  None    None                                  лапа  ...
# 698               v pl sk    None                         скамья, лавка  ...
# 831                   v j    None                                  цепь  ...
# 404                  None    None                                лосось  ...
# 405                  None    None                                  лось  ...
# 410                 v z j    None               лучник, стрелок из лука  ...
# 402                  None    None                                 ложка  ...
# 401                  None    None                                 лодка  ...
# 850            v cs yu bm    None                   чёлн, челнок, лодка  ...
# 364                    sl    None                      кровать, постель  ...
# 406                  uk j    None                                   луг  ...
# 727                  None    None                                 стена  ...
# 702                  None    None                                  след  ...
# 786                     j    None                                улитка  ...
# 708                  None    None                           смех, хохот  ...
# 707                  None    None                                смерть  ...
# 234                  ub z    None                               завтрак  ...
# 709                  None    None                                  снег  ...
# 539                 v z j    None                                 певец  ...
# 830                  None       I                                 центр  ...
# 520       ru be sh bm uk~    None                              отвёртка  ...
# 442                  None    None                       мир, свет (мир)  ...
# 682                  None    None                                  свет  ...
# 683                  None    None                                 свеча  ...
# 222                  None    None                             ель, ёлка  ...
# 685                  None    None                                свинья  ...
# 826                  None    None                         храм, церковь  ...
# 413                ub z j    None                         лягушка, жаба  ...
# 799                 v z j       G                                 факел  ...
# 863                  ub z       D                                 шутка  ...
# 385                  v yu    None           лампочка, лампа накаливания  ...
# 598  ru~ be~ uk hsb sh bm    None                     попрошайка, нищий  ...
# 648                  None    None                                 ребро  ...
# 156                  None       I                                  гель  ...
# 223                 v z j    None                                железо  ...
# 224            ru z yu mk    None                               желудок  ...
# 230                  v pl       S                                   жук  ...
# 231                 v z j    None                               журавль  ...
# 228                   v z    None                                 жизнь  ...
# 229                 v z j       I                                 жираф  ...
# 844                   z j    None                              черепаха  ...
#
#                                 sr                        mk  \
# 706       смена (у фабрици), шихта                     смена
# 789                       уништење                уништување
# 253                          зомби                     зомби
# 743                           супа                      супа
# 226                 животиња, звер                   животно
# 254                            зуб                       заб
# 252                          злато                     злато
# 27                        Летонија         Латвија, Летонија
# 387                          лабуд                     лебед
# 386                           шапа                      шепа
# 698                          клупа                     клупа
# 831          верига, ланац, синџир     верига, синџир, ланец
# 404                          лосос                     лосос
# 405                            лос                       лос
# 410         стрелац (лук и стрела)       стрелец (со стрели)
# 402                  кашика, жлица                    лажица
# 401             лађа, чамац, чунак  лотка, кајче, чун, чамец
# 850                          чамац                чун, чамец
# 364                кревет, постеља    лежиште, легло. кревет
# 406                         ливада                    ливада
# 727                            зид                       ѕид
# 702                           траг                     трага
# 786                            пуж                    полжав
# 708                           смех                      смеа
# 707                           смрт                      смрт
# 234                        доручак                   појадок
# 709                           снег                      снег
# 539                          певач                     пејач
# 830               средиште, центар          центар, средиште
# 520    одвртач, одвијач, шрафцигер        одвртка, шрафцигер
# 442                           свет                      свет
# 682                         светло          светло, светлина
# 683                          свећа                     свеќа
# 222                  смрча, смрека            смрча, оморика
# 685                          свиња                     свиња
# 826                           храм                      храм
# 413                           жаба                      жаба
# 799                          бакља                     факел
# 863  шала, шега, досетка, лакрдија                 виц, шега
# 385                       сијалица        сијалица, светилка
# 598                        просјак                   просјак
# 648                          ребро                     ребро
# 156             гел, желе, желатин                       гел
# 223                 гвожђе, железо                    железо
# 224                        желудац                  желудник
# 230                           буба                   бубачка
# 231                          ждрал                     жерав
# 228                          живот                     живот
# 229                         жирафа                    жирафа
# 844                        корњача                     желка
#
#                                  bg      cu                        de  \
# 706              !промяна (фабрика)       !           !shift (Fabrik)
# 789          унищожение, разрушение       !  !Zerstörung, Vernichtung
# 253                           зомби       !                    Zombie
# 743                           !супа       !                    !Suppe
# 226                         животно       !                      Tier
# 254                             зъб       !                      Zahn
# 252                           злато       !                      Gold
# 27                           Латвия       !                 !Lettland
# 387                           лебед       !                   !Schwan
# 386                            лапа       !                    !Pfote
# 698                 пейка, скамейка       !                     !Bank
# 831                          верига  верига                     Kette
# 404                          сьомга       !                    !Lachs
# 405                             лос       !               !Elch, Elch
# 410                         стрелец       !             !Bogenschütze
# 402                          лъжица       !                   !Löffel
# 401                           лодка       !                      Boot
# 850                           лодка       !                      Boot
# 364                           легло       !                     !Bett
# 406                          ливада       !                    !Wiese
# 727                          !стени       !                      Wand
# 702               !следа, отпечатък       !               !Spur, Spur
# 786                          !охлюв       !                 !Schnecke
# 708                     !смях, смях       !           !Lachen, Lachen
# 707                        !смъртта       !                       Tod
# 234                        !закуска       !                !Frühstück
# 709                           !сняг       !                    Schnee
# 539                           певец       !                    Sänger
# 830                          център       !                   Zentrum
# 520                       !отвертка       !          !Schraubendreher
# 442                           !свят       !                      Welt
# 682                       !светлина       !                    !Licht
# 683                           !свещ       !                    !Kerze
# 222                          !ядоха       !                    Fichte
# 685                          !прасе       !                  !Schwein
# 826                            храм       !                    Tempel
# 413                            жаба       !                    Frosch
# 799                           факел       !                    Fackel
# 863               шега, смешка, виц       !                    Scherz
# 385                          крушка       !            !die Glühbirne
# 598               !крадец на дребно       !                  !Bettler
# 648                            !Риб       !                    !Rippe
# 156                             гел       !                      !Gel
# 223                          желязо  желѣзо                     Eisen
# 224  корем, търбух, желъдък, стомах       !                     Bauch
# 230             насекомо, буболечка       !                   !Fehler
# 231                           жерав       !                     !Kran
# 228                           живот       !                     Leben
# 229                           жираф       !                   Giraffe
# 844               костенурка, желва       !               Schildkröte
#
#                                                     nl                 eo  \
# 706                          ploeg (bij ploegendienst)    !movo (fabriko)
# 789  vernietiging, vernieling, verwoesting, destructie  !detruo, ekstermo
# 253                                             zombie             zombio
# 743                                               soep              !supo
# 226                                               dier     animalo, besto
# 254                                               tand            !denton
# 252                                               goud               !oro
# 27                                             Letland            !Latvio
# 387                                              zwaan             !cigno
# 386                                               poot            !piedon
# 698                                             bankje             !benko
# 831                                     ketting, keten               ĉeno
# 404                                               zalm             !salmo
# 405                                              eland        !alko, alko
# 410                                       boogschutter         pafarkisto
# 402                                              lepel             kulero
# 401                                               boot             !boato
# 850                                               boot             !boato
# 364                                                bed              !lito
# 406                                       wei, weiland           !herbejo
# 727                                               wand              !muro
# 702                                              spoor     !spuron, trako
# 786                                               slak            !heliko
# 708                                       lach, gelach       !rido ridado
# 707                                               dood             !morto
# 234                                            ontbijt        !matenmanĝo
# 709                                             sneeuw              !neĝo
# 539                                             zanger          !kantisto
# 830                                            centrum    !centro, centro
# 520                                   schroevendraaier         !ŝraŭbilon
# 442                                             wereld             !mondo
# 682                                              licht              !lumo
# 683                                              kaars           !kandelo
# 222                                               spar             !piceo
# 685                                             varken             !porko
# 826                                             tempel            !templo
# 413                                             kikker               rano
# 799                                             toorts            !torĉon
# 863                                      grap, scherts              ŝerco
# 385                                          gloeilamp  ampolo (lumigilo)
# 598                                           bedelaar          !almozulo
# 648                                                rib              !ripo
# 156                                                gel              !ĝelo
# 223                                              ijzer               fero
# 224                                               maag            stomako
# 230                                         kever, tor         koleoptero
# 231                                         kraanvogel               gruo
# 228                                              leven               vivo
# 229                                              giraf             ĝirafo
# 844                                          schildpad            testudo
#
#     frequency intelligibility using_example
# 706      5628               !          None
# 789      6329               !          None
# 253      5824               !          None
# 743      5818               !          None
# 226      6336               !          None
# 254      6862               !          None
# 252      7599               !          None
# 27       5338               !          None
# 387      5620               !          None
# 386      3832               !          None
# 698      5503               !          None
# 831      5404               !          None
# 404      5375               !          None
# 405      7022               !          None
# 410      4535               !          None
# 402      5552               !          None
# 401      4841               !          None
# 850      6165               !          None
# 364      5434               !          None
# 406      5542               !          None
# 727      6838               !          None
# 702      6552               !          None
# 786      4552               !          None
# 708      6102               !          None
# 707      8314               !          None
# 234      6694               !          None
# 709      7086               !          None
# 539      6596               !          None
# 830      7589               !          None
# 520      3209               !          None
# 442      8936               !          None
# 682      7714               !          None
# 683      4940               !          None
# 222      3727               !          None
# 685      5141               !          None
# 826      6857               !          None
# 413      5796               !          None
# 799      3839               !          None
# 863      5061               !          None
# 385      5058               !          None
# 598      4984               !          None
# 648      4807               !          None
# 156      5290               !          None
# 223      5956               !          None
# 224      5775               !          None
# 230      5790               !          None
# 231      4039               !          None
# 228      8225               !          None
# 229      4208               !          None
# 844      5329               !          None
#
# [50 rows x 27 columns]

# %%
etymological_nouns = nouns_combined["isv"]
standard_nouns = nouns_combined["standard_spelling_isv"]

# %%
etymological_nouns.to_csv("output/nouns_etymological_spelling_with_synonyms.txt", index=False, encoding="utf-8")
standard_nouns.to_csv("output/nouns_standard_spelling_with_synonyms.txt", index=False, encoding="utf-8")

# %%
nouns_combined['isv_no_synonyms'] = nouns_combined['isv'].apply(lambda x: x.split(" / ")[0] if pd.notna(x) else x)
nouns_combined['standard_spelling_isv_no_synonyms'] = nouns_combined['standard_spelling_isv'].apply(lambda x: x.split(" / ")[0] if pd.notna(x) else x)

etymological_nouns_no_synonyms = nouns_combined['isv_no_synonyms']
standard_nouns_no_synonyms = nouns_combined['standard_spelling_isv_no_synonyms']

# %%
etymological_nouns_no_synonyms.to_csv("output/nouns_etymological_spelling_no_synonyms.txt", index=False, encoding="utf-8")
standard_nouns_no_synonyms.to_csv("output/nouns_standard_spelling_no_synonyms.txt", index=False, encoding="utf-8")
